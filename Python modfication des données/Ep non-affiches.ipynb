# %%
from operator import index

import pandas as pd
import numpy as np
import requests
import re
from simplejustwatchapi import *

# %%
def episodenonafiches(idtmdb):
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMDg4Y2JmOTRjMWVhY2RkN2E3NzZlNTYzYWZmNmMyOCIsIm5iZiI6MTc0NzMxMTgyOS44MzMsInN1YiI6IjY4MjVkY2Q1YWZjOTY2NGQ4NTVhM2E2YyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.iy7E3VfMCN5Pxw8jTIBNcTaruLFpfWZlU9PSIAffTWw"
    }
    
    url=f"https://api.themoviedb.org/3/tv/{idtmdb}?language=fr-FR"
    req=requests.get(url, headers=headers)
    numsais=[]
    data = req.json()
    res=[]
    for k in data['seasons']:
      numsais.append(k['season_number'])
    for t in numsais:
      url=f'https://api.themoviedb.org/3/tv/{idtmdb}/season/{t}?language=fr-FR'
      req=requests.get(url, headers=headers)
      data=req.json()
      for h in data['episodes']:
        res.append((str(data['season_number']) ,str(h['episode_number']),h['name']))
    return res

# %%
print(episodenonafiches(71446))
# Out:
# [('0', '1', 'Épisode 1'), ('0', '2', 'Épisode 2'), ('0', '3', 'Épisode 3'), ('0', '4', 'Épisode 4'), ('0', '5', 'Épisode 5'), ('0', '6', 'Épisode 6'), ('0', '7', 'Épisode 7'), ('0', '8', 'Épisode 8'), ('0', '9', 'Épisode 9'), ('0', '10', 'Épisode 10'), ('0', '11', 'Épisode 11'), ('0', '12', 'Épisode 12'), ('0', '13', 'Épisode 13'), ('0', '14', 'Épisode 1'), ('0', '15', 'Épisode 2'), ('0', '16', 'Épisode 3'), ('0', '17', 'Épisode 4'), ('0', '18', 'Épisode 5'), ('0', '19', 'Épisode 6'), ('0', '20', 'Épisode 7'), ('0', '21', 'Épisode 8'), ('0', '22', 'Épisode 9'), ('1', '1', 'Épisode 1'), ('1', '2', 'Épisode 2'), ('1', '3', 'Épisode 3'), ('1', '4', 'Épisode 4'), ('1', '5', 'Épisode 5'), ('1', '6', 'Épisode 6'), ('1', '7', 'Épisode 7'), ('1', '8', 'Épisode 8'), ('1', '9', 'Épisode 9'), ('1', '10', 'Épisode 10'), ('1', '11', 'Épisode 11'), ('1', '12', 'Épisode 12'), ('1', '13', 'Épisode 13'), ('1', '14', 'Épisode 14'), ('1', '15', 'Épisode 15'), ('2', '1', 'On est de retour'), ('2', '2', 
# ...

# %%
dataseries=pd.read_csv('resseriesvecteur.csv', index_col=0)
dataepisodes=pd.read_csv('dataepisodesNetflix.csv', index_col=0)
idjw=''
idtmdb=-5
prob=[]
res=[]
eta=0
for i in dataepisodes.index:
    eta+=1
    print(eta, '/', len(dataepisodes))
    try:
        if dataepisodes.loc[i, 'SVOD']=='Disney+':
            if dataseries.loc[dataseries['id']==dataepisodes.loc[i, 'idSerie'], 'idjw'].values[0]!=idjw:
                idjw=dataseries.loc[dataseries['id']==dataepisodes.loc[i, 'idSerie'], 'idjw'].values[0]
                serie=details(idjw, country="FR")
                idtmdb=serie.tmdb_id
                res=episodenonafiches(idtmdb)
            for k in res:
                if str(dataepisodes.loc[i, 'saison'])==k[0] and str(int(dataepisodes.loc[i, 'episode']))==k[1]:
                    dataepisodes.loc[i, 'titreEP']=k[2]
                    
    except Exception as e:
        prob.append((i, e))
# Out:
# 1 / 15122
# 2 / 15122
# 3 / 15122
# 4 / 15122
# 5 / 15122
# 6 / 15122
# 7 / 15122
# 8 / 15122
# 9 / 15122
# 10 / 15122
# 11 / 15122
# 12 / 15122
# 13 / 15122
# 14 / 15122
# 15 / 15122
# 16 / 15122
# 17 / 15122
# 18 / 15122
# 19 / 15122
# 20 / 15122
# 21 / 15122
# 22 / 15122
# 23 / 15122
# 24 / 15122
# 25 / 15122
# 26 / 15122
# 27 / 15122
# 28 / 15122
# 29 / 15122
# 30 / 15122
# 31 / 15122
# 32 / 15122
# 33 / 15122
# 34 / 15122
# 35 / 15122
# 36 / 15122
# 37 / 15122
# 38 / 15122
# 39 / 15122
# 40 / 15122
# 41 / 15122
# 42 / 15122
# 43 / 15122
# 44 / 15122
# 45 / 15122
# 46 / 15122
# 47 / 15122
# 48 / 15122
# 49 / 15122
# 50 / 15122
# 51 / 15122
# 52 / 15122
# 53 / 15122
# 54 / 15122
# 55 / 15122
# 56 / 15122
# 57 / 15122
# 58 / 15122
# 59 / 15122
# 60 / 15122
# 61 / 15122
# 62 / 15122
# 63 / 15122
# 64 / 15122
# 65 / 15122
# 66 / 15122
# 67 / 15122
# 68 / 15122
# 69 / 15122
# 70 / 15122
# 71 / 15122
# 72 / 15122
# 73 / 15122
# 74 / 15122
# 75 / 15122
# 76 / 15122
# 77 / 15122
# ...

# %%
prob
# Out:
# []

# %%
dataepisodes.to_csv('dataepisodesTest.csv')

# %%
serie=details('ts56768', country="FR")
idtmdb=serie.tmdb_id

# %%
dataepisodes=pd.read_csv('dataepisodesNetflix.csv', index_col=0)
dataepisodes.reset_index(drop=True, inplace=True)

# %%
dataepisodes=dataepisodes.dropna(subset='titreEP')

# %%
dataepisodes.to_csv('resepisodes.csv')
