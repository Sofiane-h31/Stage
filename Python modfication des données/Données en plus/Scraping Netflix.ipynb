# %%
import pandas as pd
import numpy as np
import requests
import re

from huggingface_hub.constants import default_assets_cache_path

dataplat=pd.read_csv('platseries.csv', index_col=0)
dataplat['ClassificationSVOD']=None

# %%
probdef=[]


def classifnetflix(url):
    url=url[:24]+'fr/'+url[24:]
    serie=True#Modifier pour les films

    headers={
        'Accept-Encoding':'identity'
    }

    site = requests.get(url, headers=headers)


    html = site.text
    #print(html)
    if site.status_code == 200:
        age = re.search(r'"contentRating":"([^"]+)"', html)
        if age:
            if serie==True:
                episodes=re.findall(r'"episodeNum":([^,]*)', html)
                episodes=[(i, age.group(1)) for i in range(1, len(episodes)+1)]
                return age.group(1), episodes
            else:
                return age.group(1)
        else:
            print("Problème d'âge :",url)
            probdef.append(url)

proburl=[]
eta=0
for i in dataplat['Diffuseur']:
    print((dataplat.loc[dataplat['Diffuseur']==i, 'title']).to_string(), '     ', eta,'/ 625')
    if 'netflix' in i:
        try:
            dataplat.loc[dataplat['Diffuseur']==i, 'ClassificationSVOD']=classifnetflix(i)[0]
        except Exception as e:
            probdef.append((i, e))
        eta+=1
            

print(probdef)
print(len(probdef))

print(probdef)
print(len(probdef))
dataplat.to_csv('dataplat.csv')
# Out:
# 0    Game of Thrones       0 / 625
# 1    Game of Thrones       0 / 625
# 2    Game of Thrones       0 / 625
# 3    Breaking Bad       0 / 625
# 4    Stranger Things       1 / 625
# 5    Friends       2 / 625
# 6    Friends       2 / 625
# 7    Friends       2 / 625
# 8    The Walking Dead       2 / 625
# 9    Sherlock       3 / 625
# 10    Sherlock       4 / 625
# 11    Chernobyl       4 / 625
# 12    Chernobyl       4 / 625
# 13    Chernobyl       4 / 625
# 14    The Big Bang Theory       4 / 625
# 15    The Big Bang Theory       4 / 625
# 16    The Big Bang Theory       4 / 625
# 17    Dexter       4 / 625
# 18    Dexter       4 / 625
# 19    Dexter       4 / 625
# 20    Dexter       4 / 625
# 21    The Boys       4 / 625
# 22    The Office       4 / 625
# 23    The Office       4 / 625
# 24    How I Met Your Mother       5 / 625
# 25    Better Call Saul       5 / 625
# ---------------------------------------------------------------------------
# ...

# %%
Name: title, dtype: object 
1
